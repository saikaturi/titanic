# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
td=pd.read_csv("titanic_dataset.csv")

# %%
td
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # initial check

# %%
td.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %% [markdown]
# # Asking question

# %%
#1.passenger class wise survival
#2.gender who survived
#3.Gender wise survival
#4.fare wise survival

# %%
td.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # univariate analysis

# %%
td["survived"].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
td["survived"].value_counts(normalize=True)
# Out:
# survived
# 0    0.616162
# 1    0.383838
# Name: proportion, dtype: float64

# %%
td["sex"].value_counts(normalize=True)
# Out:
# sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
td["pclass"].value_counts(normalize=True).sort_index(ascending=True)*100
# Out:
# pclass
# 1    24.242424
# 2    20.650954
# 3    55.106622
# Name: proportion, dtype: float64

# %%
td["age"].value_counts(normalize=True).max()
# Out:
# 0.04201680672268908

# %%
td["sex"].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
td["sex"].value_counts(normalize=True)
# Out:
# sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
td["sex"].value_counts(normalize=True)*100
# Out:
# sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64

# %%
td["sex"].value_counts(normalize=True).sort_index(ascending=True)*100
# Out:
# sex
# female    35.241302
# male      64.758698
# Name: proportion, dtype: float64

# %%
td["class"].value_counts(normalize=True).sort_index(ascending=True)*100
# Out:
# class
# First     24.242424
# Second    20.650954
# Third     55.106622
# Name: proportion, dtype: float64

# %%
td["who"].value_counts()
# Out:
# who
# man      537
# woman    271
# child     83
# Name: count, dtype: int64

# %%
td["who"].value_counts(normalize=True)*100
# Out:
# who
# man      60.269360
# woman    30.415264
# child     9.315376
# Name: proportion, dtype: float64

# %%
td["age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: age, dtype: float64

# %%
td["fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
td["sibsp"].value_counts()
# Out:
# sibsp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
td["sibsp"].value_counts(normalize=True)
# Out:
# sibsp
# 0    0.682379
# 1    0.234568
# 2    0.031425
# 4    0.020202
# 3    0.017957
# 8    0.007856
# 5    0.005612
# Name: proportion, dtype: float64

# %%
td["sibsp"].value_counts(normalize=True)*100
# Out:
# sibsp
# 0    68.237935
# 1    23.456790
# 2     3.142536
# 4     2.020202
# 3     1.795735
# 8     0.785634
# 5     0.561167
# Name: proportion, dtype: float64

# %%
td["parch"].value_counts()
# Out:
# parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
td["sibsp"].value_counts(normalize=True)*100
# Out:
# sibsp
# 0    68.237935
# 1    23.456790
# 2     3.142536
# 4     2.020202
# 3     1.795735
# 8     0.785634
# 5     0.561167
# Name: proportion, dtype: float64

# %%
sns.countplot(data=td,x="survived")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=td,x="survived",hue="sex")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=td,x="survived",hue="deck")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=td,x="survived",hue="alone")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=td,x="survived",hue="who")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=td,x="sex")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=td,x="survived",hue="embarked")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=td,x="survived",hue="age")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=td,x="survived",hue="embark_town")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=td,x="survived",hue="adult_male")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=td,x="survived",hue="alive")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.countplot(data=td,x="survived",hue="alone")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.histplot(data=td,x="age",hue="survived")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.countplot(data=td,x="age",hue="sibsp")
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
sns.kdeplot(data=td,x="age",hue="parch")
# Out:
# C:\Users\saika\AppData\Local\Temp\ipykernel_26816\2782599401.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=td,x="age",hue="parch")
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.kdeplot(data=td,x="age",hue="survived")
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.histplot(data=td,x="age",hue="survived",kde=True)
plt.title('Survival Count by Age')
# Out:
# Text(0.5, 1.0, 'Survival Count by Age')

# %%
sns.histplot(data=td,x="who",hue="survived",kde=True)
plt.title('Survival Count by who')
# Out:
# Text(0.5, 1.0, 'Survival Count by who')

# %%
sns.histplot(data=td,x="age",hue="pclass",kde=True)
plt.title('Survival Count by Age')
# Out:
# Text(0.5, 1.0, 'Survival Count by Age')

# %%
sns.histplot(data=td,x="age",hue="parch",kde=True)
plt.title('Survival Count by Age')
# Out:
# Text(0.5, 1.0, 'Survival Count by Age')

# %%
sns.histplot(data=td,x="age",hue="sex",kde=True)
plt.title('Survival Count by Age')
# Out:
# Text(0.5, 1.0, 'Survival Count by Age')

# %%
sns.histplot(data=td,x="age",hue="deck",kde=True)
plt.title('Survival Count by Age')
# Out:
# Text(0.5, 1.0, 'Survival Count by Age')

# %%
sns.histplot(data=td,x="age",hue="alone",kde=True)
plt.title('Survival Count by Age')
# Out:
# Text(0.5, 1.0, 'Survival Count by Age')

# %% [markdown]
# # Conclusion

# %%
In this project frist we have to download the dataset.Later Understand the dataset completely.Without understand the dataset we cannot do these project.
use the head() and tail() ,info() and some others methods .apply the different methods on dataset.Apply the plots and visualization on datasets.
